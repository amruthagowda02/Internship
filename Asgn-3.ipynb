# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import requests
import numpy as np
import re
import requests

# %%
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# # Q1

# %%
val=input("enter your item ")
# Out:
# enter your item guitar

# %%
driver=webdriver.Chrome()
driver.get("https://www.amazon.in/")

# %%
slct=driver.find_element(By.CLASS_NAME,"nav-search-field ")
slct.click()

# %%
srch = driver.find_element(By.ID, "twotabsearchtextbox")
srch.send_keys('guitar')

# %%
go=driver.find_element(By.XPATH,'//div[@class="nav-search-submit nav-sprite"]//span')
go.click()

# %%
urls = []
start = 0
end = 3

for page in range(start, end):
   
    elements = driver.find_elements(By.XPATH, '//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for element in elements:
        urls.append(element.get_attribute('href'))
    
for url in urls:
    print(url)
# Out:
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0OTcxMjAxODAwOTM3NjM5OjE2OTYyNjUzNDQ6c3BfYXRmOjMwMDA2NTYzMDkyNTkzMjo6MDo6&url=%2FWOODEN-DOLPHIN-Beginner-Starter-SUNBRUST%2Fdp%2FB0CK4QJPX9%2Fref%3Dsr_1_1_sspa%3Fcrid%3D3VNYTVT6LBVXI%26keywords%3Dguitar%26qid%3D1696265344%26sprefix%3Dguitar%252Caps%252C247%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0OTcxMjAxODAwOTM3NjM5OjE2OTYyNjUzNDQ6c3BfYXRmOjMwMDA2NTYzMDkyNjEzMjo6MDo6&url=%2FWOODEN-DOLPHIN-Beginner-Starter-SUNBRUST%2Fdp%2FB0CK4Q5XP7%2Fref%3Dsr_1_2_sspa%3Fcrid%3D3VNYTVT6LBVXI%26keywords%3Dguitar%26qid%3D1696265344%26sprefix%3Dguitar%252Caps%252C247%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0OTcxMjAxODAwOTM3NjM5OjE2OTYyNjUzNDQ6c3BfYXRmOjMwMDA2NTYzMDkyNjQzMjo6MDo6&url=%2FWOODEN-DOLPHIN-Beginner-Starter-SUNBRUST%2Fdp%2FB0CK4Q4FCZ%2Fref%3Dsr_1_3_sspa%3Fcrid%3D3VNYTVT6LBVXI%26keywords%3Dguitar%26qid%3D1696265344%26sprefix%3Dguitar%252Caps%252C247%26sr%3D8-3-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0OTcxMjAxODAwOTM3NjM5OjE2OTYyNjUzNDQ6c3BfYXRmOjMwMDA2NTYzMDkyNjIzMjo6MDo6&url=%2FWOODEN-DOLPHIN-Guitar-Beginner-Starter%2Fdp%2FB0CK4QB9HH%2Fref%3Dsr_1_4_sspa%3Fcrid%3D3VNYTVT6LBVXI%26keywords%3Dguitar%26qid%3D1696265344%26sprefix%3Dguitar%252Caps%252C247%26sr%3D8-4-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# https://www.amazon.in/Juarez-Acoustic-Cutaway-038C-Strings/dp/B017NPCSLI/ref=sr_1_5?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-5
# https://www.amazon.in/Intern-INT-38C-Acoustic-Guitar-Black/dp/B073B6TQQY/ref=sr_1_6?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-6
# https://www.amazon.in/EA40TBK-Premium-Spruce-Top-Cutaway-Acoustic/dp/B0BW3QYHV1/ref=sr_1_7?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-7
# https://www.amazon.in/Intern-INT-38C-Acoustic-Guitar-Sunburst/dp/B073B5MJRM/ref=sr_1_8?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-8
# https://www.amazon.in/Intern-INT-38C-BK-G-Guitar-Kit-Black/dp/B07K9497RC/ref=sr_1_9?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-9
# https://www.amazon.in/Yamaha-F280-Acoustic-Guitar-Natural/dp/B08317Y4VP/ref=sr_1_10?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-10
# https://www.amazon.in/Intern-INT-38C-Acoustic-Guitar-Blue/dp/B073B5RZBV/ref=sr_1_11?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-11
# https://www.amazon.in/JUAREZ-JRZ38C-Acoustic-Sunburst-Strings/dp/B01FYYTDTU/ref=sr_1_12?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-12
# https://www.amazon.in/Henrix-40-Inch-Cutaway-Acoustic-Guitar/dp/B0B46MGFXH/ref=sr_1_13?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-13
# https://www.amazon.in/Lindenwood-Cutaway-Acoustic-Plectrums-sunburst/dp/B085HV4YW7/ref=sr_1_14?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-14
# https://www.amazon.in/Kadence-Frontier-Acoustic-Guitar-Strings/dp/B01GDZ46AA/ref=sr_1_15?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-15
# https://www.amazon.in/Yamaha-FS-100C-6-String-Acoustic-without/dp/B00PAS9CK6/ref=sr_1_16?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-16
# https://www.amazon.in/JUAREZ-JRZ38C-Acoustic-Sunburst-Strings/dp/B01FYYTDS6/ref=sr_1_17?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8
crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-55
# https://www.amazon.in/Kadence-Guitar-learning-Acoustic-Lavender/dp/B0CD4CNSPJ/ref=sr_1_56?crid=3VNYTVT6LBVXI&keywords=guitar&qid=1696265344&sprefix=guitar%2Caps%2C247&sr=8-56
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0OTcxMjAxODAwOTM3NjM5OjE2OTYyNjUzNDQ6c3BfYnRmOjIwMTYwOTQxODA4NDk4OjowOjo&url=%2FGibzs-FT-G41-Frontier-Acoustic-Strings%2Fdp%2FB0BY5DBMVW%2Fref%3Dsr_1_57_sspa%3Fcrid%3D3VNYTVT6LBVXI%26keywords%3Dguitar%26qid%3D1696265344%26sprefix%3Dguitar%252Caps%252C247%26sr%3D8-57-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9idGY%26psc%3D1
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0OTcxMjAxODAwOTM3NjM5OjE2OTYyNjUzNDQ6c3BfYnRmOjMwMDA2NTI4NzkxMDYzMjo6MDo6&url=%2FSwan7-SW40C-AMH-All-Mahogany-Bag%2Fdp%2FB0BSS2K24F%2Fref%3Dsr_1_58_sspa%3Fcrid%3D3VNYTVT6LBVXI%26keywords%3Dguitar%26qid%3D1696265344%26sprefix%3Dguitar%252Caps%252C247%26sr%3D8-58-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9idGY%26psc%3D1
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0OTcxMjAxODAwOTM3NjM5OjE2OTYyNjUzNDQ6c3BfYnRmOjMwMDA2NTI3MDcyNzUzMjo6MDo6&url=%2FGT-KIT-003-Changing-Multicolored-Acoustic%2Fdp%2FB0C28BNXJW%2Fref%3Dsr_1_59_sspa%3Fcrid%3D3VNYTVT6LBVXI%26keywords%3Dguitar%26qid%3D1696265344%26sprefix%3Dguitar%252Caps%252C247%26sr%3D8-59-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9idGY%26psc%3D1
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0OTcxMjAxODAwOTM3NjM5OjE2OTYyNjUzNDQ6c3BfYnRmOjMwMDA1OTE1MzU1NTAzMjo6MDo6&url=%2FGuitar-Bridge-Puller-Beginners-Accessories%2Fdp%2FB0C2CR19MK%2Fref%3Dsr_1_60_sspa%3Fcrid%3D3VNYTVT6LBVXI%26keywords%3Dguitar%26qid%3D1696265344%26sprefix%3Dguitar%252Caps%252C247%26sr%3D8-60-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9idGY%26psc%3D1

# %%
len(urls)
# Out:
# 144

# %%
brand=[]
for url in urls:
    driver.get(url)
    time.sleep(2)
    try:
        brands = driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-medium brand-snapshot-flex-row"]/p/span')
        for brand_element in brands:
            brand.append(brand_element.text)
    except NoSuchElementException:
        brand.append('-')

print(brand)
# Out:
# ['Kadence', 'REVEL', 'JUAREZ', 'VAULT', 'Intern', 'Henrix', 'Intern', 'Intern', 'YAMAHA', 'Intern', 'JUAREZ', 'Intern', 'Kadence', 'REVEL', 'JUAREZ', 'YAMAHA', 'Intern', 'JUAREZ', 'Kadence', 'DEVICE OF URBAN INFOTECH', 'YAMAHA', 'Kadence', 'JUAREZ', 'YAMAHA', 'MUSTANG', 'Intern', 'Kadence', 'VAULT', 'VAULT', 'Ibanez', 'blueberry', 'Fender', 'Henrix', 'Medellin', 'Intern', 'Intern', 'VAULT', 'YAMAHA', 'JUAREZ', 'VAULT', 'VAULT', 'YAMAHA', 'JUAREZ', 'YAMAHA', 'VAULT', 'Kadence', 'Fender', 'Kadence', 'Ibanez', 'Kadence', 'REVEL', 'DEVICE OF URBAN INFOTECH', 'VAULT', 'Fender', 'VAULT', 'Medellin', 'JUAREZ', 'blueberry', 'JUAREZ', 'YAMAHA', 'VAULT', 'JUAREZ', 'Kadence', 'Medellin', 'Kadence', 'YAMAHA', 'blueberry', 'Kadence', 'Kadence', 'Kadence', 'Intern', 'Henrix', 'VAULT', 'JUAREZ', 'Kadence', 'YAMAHA', 'Fender', 'YAMAHA', 'JUAREZ', 'Kadence', 'Intern', 'JUAREZ', 'JUAREZ', 'Fender', 'Kadence', 'Intern', 'VAULT', 'Intern', 'JUAREZ', 'Intern']

# %%
len(brand)
# Out:
# 90

# %% [markdown]
# # Q2

# %%
"brand name", "name of product","price","return/exchange","expected delivery","availability"

# %%
brand=[]
product=[]
price=[]
rtex=[]
deli=[]
avail=[]
purl=[]

# %%
for url in urls:
    driver.get(url)
    
    try:
        brands = driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-medium brand-snapshot-flex-row"]/p/span')
        for brand_element in brands:
            brand.append(brand_element.text)
    except NoSuchElementException:
        brand.append('-')
        
    try:
        products = driver.find_elements(By.XPATH,'//span[@class="a-size-large product-title-word-break"]')
        for i in products:
            PP = i.text
            product.append(PP)
    except NoSuchElementException:
        product.append('-')
        
    try:
        prices = driver.find_elements(By.XPATH,'//span[@class="a-price aok-align-center reinventPricePriceToPayMargin priceToPay"]/span[2]/span[2]')
        for i in prices:
            P = i.text
            price.append(P)
    except NoSuchElementException:
        price.append('-')
        
    try:
        rtexs = driver.find_elements(By.XPATH,'//li[3][@class="a-carousel-card tw-scroll-carousel-element"]/div/span/div[2]/span')
        for i in rtexs:
            r = i.text
            rtex.append(r)
    except NoSuchElementException:
        rtex.append('-')
        
    try:
        deliv= driver.find_elements(By.XPATH,'//div[@class="a-spacing-base"]//span[@class="a-text-bold"]')
        for i in deliv:
            d = i.text
            deli.append(d)
    except NoSuchElementException:
        deli.append('-')
        
    try:
        avails= driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-none a-spacing-top-micro }"]')
        for i in avails:
            a = i.text
            avail.append(a)
    except NoSuchElementException:
        avail.append('-')

# %%
print(len(brand), len(product), len(price), len(rtex), len(deli), len(avail))
# Out:
# 178 224 223 207 224 222

# %%
df = pd.DataFrame({'BRAND': brand[:177], 'PRODUCT': product[:177], 'PRICE': price[:177], 'RETURN': rtex[:177], 'DELIVERY': deli[:177], 'AVAILABILITY': avail[:177]})
df
# Out:
#         BRAND                                            PRODUCT   PRICE  \
# 0      YAMAHA  Martin LX1E Little Martin Solid Sitka Spruce/M...  54,425
# 1     Kadence  Yamaha 16 Incheses wood Acoustic Guitar F280 D...   8,450
# 2       VAULT  PS Signature 41inch Acoustic Guitar (Natural C...   3,419
# 3     Kadence  Kadence AstroMan Electric Guitar, 21 FRETS, RO...   9,999
# 4      JUAREZ               Vault Compressor Guitar Effect Pedal   3,419
# ..        ...                                                ...     ...
# 172  Medellin  Intern INT-38C-BK-G Cutaway Right Handed Acous...   7,499
# 173   Kadence  Yamaha F280 Acoustic Rosewood Guitar (Natural,...   2,299
# 174    Intern          Intern INT-38C Acoustic Guitar Kit (Blue)   1,764
# 175    JUAREZ  Juarez Lindenwood Acoustic Guitar Kit, 38 Inch...   3,499
# 176    Intern  Henrix 40C 40-Inch Cutaway Acoustic Guitar wit...   1,899
#
#                  RETURN              DELIVERY          AVAILABILITY
# 0    7 days Replacement   Saturday, 7 October  Only 1 left in stock
# 1    7 days Replacement     Monday, 9 October              In stock
# 2    7 days Replacement     Sunday, 8 October              In stock
# 3    7 days Replacement   Thursday, 5 October              In stock
# 4    7 days Replacement  Wednesday, 4 October              In stock
# ..                  ...                   ...                   ...
# 172   7 days Returnable  Wednesday, 4 October              In stock
# 173  7 days Replacement     Friday, 6 October              In stock
# 174  7 days Replacement     Sunday, 8 October              In stock
# 175  7 days Replacement     Friday, 6 October              In stock
# 176  7 days Replacement  Wednesday, 4 October              In stock
#
# [177 rows x 6 columns]

# %%
print(len(brand), len(product), len(price), len(rtex), len(deli), len(avail))
# Out:
# 178 224 223 207 224 222

# %% [markdown]
# # Q3

# %%
driver=webdriver.Chrome()
driver.get("https://images.google.com/")

# %%
slct=driver.find_element(By.CLASS_NAME,"gLFyf")
slct.click()

# %%
srch = driver.find_element(By.CLASS_NAME,"gLFyf")
srch.send_keys('fruits')

# %%
go=driver.find_element(By.CLASS_NAME,"zgAlFc")
go.click()

# %%
for _ in range(20): # scroll 20 times till 100 images are obtained
    driver.execute_script("window.scrollBy(0,100)")
images=driver.find_elements(By.CLASS_NAME,'rg_i.Q4LuWd')
url=[]
for i in images:
    source=i.get_attribute('src')# src for image class
    if source is not None:
        if(source[0:4]=='http'):
            url.append(source)
for i in range(len(url)):
    if i >10:
        breakBy.XPATH,
    print("dwld {0} of {1} img".format(i,10))
    response=requests.get(url[i])
    file=open(r'C:\Users\LENOVO\OneDrive\Desktop\data trained'+str(i)+".jpg","wb")
    file.write(response.content)

# %% [markdown]
# # Q4

# %%
driver=webdriver.Chrome()
driver.get("https://www.flipkart.com/")

# %%
slct=driver.find_element(By.CLASS_NAME,"_2SmNnR")
slct.click()

# %%
srch = driver.find_element(By.CLASS_NAME,"Pke_EE")
srch.send_keys('Oneplus Nord')

# %%
go=driver.find_element(By.CLASS_NAME,"_2iLD__")
go.click()

# %%
# brand=[]
name=[]
col=[]
ram=[]
rom=[]
Pcam=[]
Scam=[]
size=[]
bat=[]
P=[]
url=[]

# %%
names = driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
for i in names:
    bb = i.text
    name.append(bb)

colors = driver.find_elements(By.XPATH, '//div[@class="_4rR01T"]')
for i in colors:
    cc = i.text
    match = re.search(r'\(([^,]+),', cc) 
    if match:
        text = match.group(1).strip()
        col.append(text)

ra = driver.find_elements(By.XPATH, '//ul[@class="_1xgFaf"]/li[1]')
for i in ra:
    rr = i.text
    match = re.search(r'(\d+\s*GB\s*RAM)', rr)
    if match:
        text = match.group(0).strip()
        ram.append(text) 

ro = driver.find_elements(By.XPATH, '//ul[@class="_1xgFaf"]/li[1]')
for i in ro:
    rrr = i  
    match = re.search(r'(\d+\s*GB\s*ROM)', rrr.text)
    if match:
        text = match.group(0).strip()
        rom.append(text)  

prim = driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[3]')
for i in prim:
    pp = i.text
    Pcam.append(pp)
BAT = driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[4]')
for i in BAT:
    bats = i.text
    bat.append(bats)
SIZ = driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[2]')
for i in SIZ:
    siz = i.text
    size.append(siz)
P=[]
PRI = driver.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')
for element in PRI:
    pri = element.text
    P.append(pri)

# %%
print(len(name),len(col),len(ram),len(rom),len(Pcam),len(bat),len(size),len(P))
# Out:
# 24 24 24 24 24 24 24 24

# %%
df=pd.DataFrame({'NaME':name,'colour':col,'RAM':ram,'ROM':rom,'camera':Pcam,'Battery':bat,"SIZE":size,'Price':P})
df
# Out:
#                                                  NaME          colour  \
# 0     OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)     Pastel Lime
# 1     OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)     Pastel Lime
# 2      OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)      Black Dusk
# 3   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...  Chromatic Gray
# 4       OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)       Blue Tide
# 5            OnePlus Nord CE3 5G (Aqua Surge, 128 GB)      Aqua Surge
# 6          OnePlus Nord CE3 5G (Grey Shimmer, 256 GB)    Grey Shimmer
# 7             OnePlus Nord 3 5G (Misty Green, 128 GB)     Misty Green
# 8            OnePlus Nord 3 5G (Tempest Gray, 128 GB)    Tempest Gray
# 9             OnePlus Nord 3 5G (Misty Green, 256 GB)     Misty Green
# 10           OnePlus Nord 2T 5G (Gray Shadow, 128 GB)     Gray Shadow
# 11         OnePlus Nord CE3 5G (Grey Shimmer, 128 GB)    Grey Shimmer
# 12           OnePlus Nord 3 5G (Tempest Gray, 256 GB)    Tempest Gray
# 13           OnePlus Nord CE3 5G (Aqua Surge, 256 GB)      Aqua Surge
# 14         OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)     Bahama Blue
# 15              OnePlus Nord 2T 5G (Jade Fog, 256 GB)        Jade Fog
# 16          OnePlus Nord CE 5G (Charcoal Ink, 128 GB)    Charcoal Ink
# 17              OnePlus Nord 2 5G (Blue Haze, 128 GB)       Blue Haze
# 18            OnePlus Nord 2 5G (Gray Sierra, 128 GB)     Gray Sierra
# 19            OnePlus Nord 2 5G (Gray Sierra, 256 GB)     Gray Sierra
# 20              OnePlus Nord 2 5G (Blue Haze, 256 GB)       Blue Haze
# 21                OnePlus Nord 2 5G (PAC-MAN, 256 GB)         PAC-MAN
# 22            OnePlus Nord 2 5G (Gray Sierra, 256 GB)     Gray Sierra
# 23  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...  Chromatic Gray
#
#           RAM         ROM                                camera  \
# 0    8 GB RAM  128 GB ROM                     108MP Rear Camera
# 1    8 GB RAM  256 GB ROM                     108MP Rear Camera
# 2    6 GB RAM  128 GB ROM  64MP Rear Camera | 16MP Front Camera
# 3    8 GB RAM  256 GB ROM                     108MP Rear Camera
# 4    6 GB RAM  128 GB ROM  64MP Rear Camera | 16MP Front Camera
# 5    8 GB RAM  128 GB ROM                      50MP Rear Camera
# 6   12 GB RAM  256 GB ROM                      50MP Rear Camera
# 7    8 GB RAM  128 GB ROM                      50MP Rear Camera
# 8    8 GB RAM  128 GB ROM                      50MP Rear Camera
# 9   16 GB RAM  256 GB ROM                      50MP Rear Camera
# 10   8 GB RAM  128 GB ROM  50MP Rear Camera | 32MP Front Camera
# 11   8 GB RAM  128 GB ROM                      50MP Rear Camera
# 12  16 GB RAM  256 GB ROM                      50MP Rear Camera
# 13  12 GB RAM  256 GB ROM                      50MP Rear Camera
# 14   8 GB RAM  128 GB ROM                      64MP Rear Camera
# 15  12 GB RAM  256 GB ROM                      50MP Rear Camera
# 16   8 GB RAM  128 GB ROM                      64MP Rear Camera
# 17   8 GB RAM  128 GB ROM                      50MP Rear Camera
# 18   8 GB RAM  128 GB ROM                      50MP Rear Camera
# 19  12 GB RAM  256 GB ROM                      50MP Rear Camera
# 20  12 GB RAM  256 GB ROM                      50MP Rear Camera
# 21  12 GB RAM  256 GB ROM                      50MP Rear Camera
# 22  12 GB RAM  256 GB ROM                      50MP Rear Camera
# 23   8 GB RAM  128 GB ROM                     108MP Rear Camera
#
#              Battery                          SIZE    Price
# 0   5000 mAh Battery  17.07 cm (6.72 inch) Display  ₹19,999
# 1   5000 mAh Battery  17.07 cm (6.72 inch) Display  ₹21,997
# 2   5000 mAh Battery  16.74 cm (6.59 inch) Display  ₹17,140
# 3   5000 mAh Battery  17.07 cm (6.72 inch) Display  ₹21,999
# 4   5000 mAh Battery  16.74 cm (6.59 inch) Display  ₹17,200
# 5   5000 mAh Battery   17.02 cm (6.7 inch) Display  ₹26,131
# 6   5000 mAh Battery   17.02 cm (6.7 inch) Display  ₹28,839
# 7   5000 mAh Battery  17.12 cm (6.74 inch) Display  ₹32,700
# 8   5000 mAh Battery  17.12 cm (6.74 inch) Display  ₹31,750
# 9   5000 mAh Battery  17.12 cm (6.74 inch) Display  ₹37,377
# 10  4500 mAh Battery   17.02 cm (6.7 inch) Display  ₹28,990
# 11  5000 mAh Battery   17.02 cm (6.7 inch) Display  ₹26,648
# 12  5000 mAh Battery  17.12 cm (6.74 inch) Display  ₹37,970
# 13  5000 mAh Battery   17.02 cm (6.7 inch) Display  ₹32,999
# 14  4500 mAh Battery  16.33 cm (6.43 inch) Display  ₹24,990
# 15  4500 mAh Battery   17.02 cm (6.7 inch) Display  ₹33,890
# 16  4500 mAh Battery  16.33 cm (6.43 inch) Display  ₹24,990
# 17  4500 mAh Battery  16.33 cm (6.43 inch) Display  ₹30,599
# 18  4500 mAh Battery  16.33 cm (6.43 inch) Display  ₹30,599
# 19  4500 mAh Battery  16.33 cm (6.43 inch) Display  ₹34,999
# 20  4500 mAh Battery  16.33 cm (6.43 inch) Display  ₹34,999
# 21  4500 mAh Battery  16.33 cm (6.43 inch) Display  ₹37,999
# 22  4500 mAh Battery  16.33 cm (6.43 inch) Display  ₹33,990
# 23  5000 mAh Battery  17.07 cm (6.72 inch) Display  ₹19,989

# %%
path = 'Phoneoutput.csv'
df.to_csv(path, index=True) 
print(f'DataFrame saved to ',path)
# Out:
# DataFrame saved to  Phoneoutput.csv

# %% [markdown]
# # Q5

# %%
#Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver=webdriver.Chrome()
driver.get("https://www.google.com/maps/")

# %%
srch = driver.find_element(By.ID,"searchboxinput")
srch.send_keys('bangalore')

# %%
go=driver.find_element(By.CLASS_NAME,"pzfvzf")
go.click()

# %%
try:
    url = driver.current_url
    print("Extracted URL:", url)
    lat_lng = re.findall(r'@([-0-9.]+),([-0-9.]+)', url)
    if lat_lng:
        latitude, longitude = lat_lng[0]
        print("Latitude:", latitude)
        print("Longitude:", longitude)
except Exception as e:
    print("An error occurred:", str(e))
# Out:
# Extracted URL: https://www.google.com/maps/place/Bengaluru,+Karnataka/@12.9544595,77.3012649,10z/data=!3m1!4b1!4m6!3m5!1s0x3bae1670c9b44e6d:0xf8dfc3e8517e4fe0!8m2!3d12.9715987!4d77.5945627!16zL20vMDljMTc?entry=ttu
# Latitude: 12.9544595
# Longitude: 77.3012649

# %% [markdown]
# # Q6

# %%
driver=webdriver.Chrome()
driver.get("https://www.digit.in/")

# %%
go=driver.find_element(By.XPATH,'//li[@class="rh-subitem-menus rh-megamenu menu-item menu-item-type-post_type_archive menu-item-object-top-products"]')
go.click()

# %%
go=driver.find_element(By.XPATH,'//div[@class="main-side clearfix full_width"]/div/div[2]/div[6]/p/a')
go.click()

# %%
try:
    name=[]
    names = driver.find_elements(By.XPATH,'//h3[@class="font130 mt0 mb10 mobilesblockdisplay "]')
    for i in names:
        bb = i.text
        name.append(bb)
except NoSuchElementException:
    name.append('-')
try:
    os=[]
    oss = driver.find_elements(By.XPATH,'//div[@class="woo_code_zone_loop clearbox"]/div[1]/div/span[2]')
    for i in oss:
        ss = i.text
        os.append(ss)
except NoSuchElementException:
    os.append('-')
try:
    dis=[]
    disps = driver.find_elements(By.XPATH,'//div[@class="woo_code_zone_loop clearbox"]/div[2]/div/span[2]')
    for i in disps:
        pp = i.text
        dis.append(pp)
except NoSuchElementException:
    dis.append('-')
try:
    res=[]
    ress = driver.find_elements(By.XPATH,'//div[@class="woo_code_zone_loop clearbox"]/div[3]/div/span[2]')
    for i in ress:
        s = i.text
        res.append(s)
except NoSuchElementException:
    res.append('-')

try:
    pro=[]
    pros = driver.find_elements(By.XPATH,'//div[@class="woo_code_zone_loop clearbox"]/div[3]/div/span[2]')
    for i in pros:
        b = i.text
        pro.append(b)
except NoSuchElementException:
    pro.append('-')
try:
    des=[]
    dess = driver.find_elements(By.XPATH,'//div[@class="cegg-no-top-margin cegg-list-logo-title"]/a')
    for i in dess:
        d = i.text
        des.append(d)
except NoSuchElementException:
    des.append('-')
try:
    pri=[]
    pris = driver.find_elements(By.XPATH,'//div[@class="cegg-price cegg-price-color cegg-price-instock"]')
    for i in pris:
        pr = i.text
        pri.append(pr)
except NoSuchElementException:
    pri.append('-')

# %%
df = pd.DataFrame({'BRAND': name[:4], 'operating system': os[:4], 'PRICE': pri[:4], 'describe': des[:4], 'processor': pro[:4],'resolution':res[:4],'display size':dis[:4]})
df
# Out:
#                                    BRAND operating system        PRICE  \
# 0    Apple MacBook Air 2022 M2 MLY03HN/A              iOS  Rs. 106,990
# 1           Samsung Galaxy Book3 Pro 360  Windows 11 Home  Rs. 186,500
# 2   Lenovo Yoga 9i13th Gen Core i7-1360P              Mac   Rs. 12,999
# 3  Apple MacBook Pro M2 (2023-MPHK3HN/A)       Windows 11   Rs. 14,990
#
#                                             describe    processor  \
# 0  Apple 2022 MacBook Air Laptop with M2 chip: 34...  2560 x 1600
# 1  Dell XPS 13 Plus Laptop, Intel Core i7-1260P, ...  2880 x 1800
# 2                                                     3840 x 2400
# 3                                                     1920 x 1080
#
#     resolution display size
# 0  2560 x 1600         13.6
# 1  2880 x 1800           14
# 2  3840 x 2400         14.2
# 3  1920 x 1080         13.4

# %% [markdown]
# # Q7

# %%
driver=webdriver.Chrome()
driver.get("https://www.forbes.com/")

# %%
slct=driver.find_element(By.XPATH,'//div[@class="_8FT-x3t4"]/div')
slct.click()

# %%
go = driver.find_element(By.XPATH, '//li[@class="TjJgrPSg _2bNo56RE secondary"]/a[1]')

go.click()

# %%
rank=[]
name=[]
net=[]
AGE=[]
cnt=[]
src=[]
ind=[]

# %%
ranks = driver.find_elements(By.XPATH,'//div[@class="Table_rank___YBhk Table_dataCell__2QCve"]')
for i in ranks:
    rk = i.text
    rank.append(rk)


names = driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[2]')
for i in names:
    bb = i.text
    name.append(bb)


nets = driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[3]')
for i in nets:
    n = i.text
    net.append(n)

ages = driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[4]')
for i in ages:
    age = i.text
    AGE.append(age)



cnts = driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[5]')
for i in cnts:
    c = i.text
    cnt.append(c)

srcs = driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[6]')
for i in srcs:
    s = i.text
    src.append(s)

inds = driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[7]')
for i in inds:
    indus = i.text
    ind.append(indus)

# %%
df=pd.DataFrame({'RANK':rank,'NAME':name,'NET':net,'AGE':AGE,'COUNTRY':cnt,'SOURCE':src,"INDUSTRY":ind})
df
# Out:
#     RANK                      NAME     NET AGE        COUNTRY  \
# 0      1  Bernard Arnault & family  $211 B  74         France
# 1      2                 Elon Musk  $180 B  51  United States
# 2      3                Jeff Bezos  $114 B  59  United States
# 3      4             Larry Ellison  $107 B  78  United States
# 4      5            Warren Buffett  $106 B  92  United States
# ..   ...                       ...     ...  ..            ...
# 195  195               Jin Baofang  $9.6 B  70          China
# 196  195        Luo Liguo & family  $9.6 B  67          China
# 197  195              Marijke Mars  $9.6 B  58  United States
# 198  195               Pamela Mars  $9.6 B  62  United States
# 199  195              Valerie Mars  $9.6 B  64  United States
#
#                  SOURCE               INDUSTRY
# 0                  LVMH       Fashion & Retail
# 1         Tesla, SpaceX             Automotive
# 2                Amazon             Technology
# 3                Oracle             Technology
# 4    Berkshire Hathaway  Finance & Investments
# ..                  ...                    ...
# 195        Solar panels                 Energy
# 196           Chemicals          Manufacturing
# 197     Candy, pet food        Food & Beverage
# 198     Candy, pet food        Food & Beverage
# 199     Candy, pet food        Food & Beverage
#
# [200 rows x 7 columns]

# %% [markdown]
# # Q8

# %%
driver=webdriver.Chrome()
driver.get("https://www.youtube.com/")
slct=driver.find_element(By.CLASS_NAME,"style-scope ytd-rich-grid-media")
slct.click()
cnt=[]
time=[]
vote=[]
for _ in range(1000): 
    driver.execute_script("window.scrollBy(0,1000)")
cnts = driver.find_elements(By.XPATH,'//div[@class="style-scope ytd-comment-renderer"]/div[2]/div[2]')
for i in cnts:
    c = i.text
    cnt.append(c)
times = driver.find_elements(By.XPATH,'//div[@class="style-scope ytd-comment-renderer"]/yt-formatted-string')
for i in times:
    lk = i.text
    time.append(lk)
votes = driver.find_elements(By.XPATH,'//div[@class="style-scope ytd-comment-action-buttons-renderer"]/span[2]')
for i in votes:
    vt = i.text
    vote.append(vt)

# %%
df=pd.DataFrame({'comment':cnt[:120],'uploaded':time[:120],'upvotes':vote[:120]})
df
# Out:
#                                                comment              uploaded  \
# 0                                  I love Allu Arjun ️          8 months ago
# 1    This is an awesome movie based on real life. I...  1 month ago (edited)
# 2    This movie makes me realise how parents love u...            9 days ago
# 3     The Acting is so good \n\n        But!!!!!!!\...            5 days ago
# 4    What a great message. It takes so many years t...   1 year ago (edited)
# ..                                                 ...                   ...
# 115                                                दिल           2 years ago
# 116                       Really heart touching movie           7 months ago
# 117                                                              3 years ago
# 118  At first bengali film 'Sedin Dekha Hoyechilo' ...          9 months ago
# 119                      Allu arjun my favourite actor           3 years ago
#
#     upvotes
# 0        48
# 1        11
# 2         5
# 3         3
# 4       103
# ..      ...
# 115       7
# 116       7
# 117      11
# 118       3
# 119      27
#
# [120 rows x 3 columns]

# %% [markdown]
# # Q9

# %%
hostel name, distance from city centre, ratings, total reviews, overall
reviews, privates from price, dorms from price, facilities and property description.

# %%
driver=webdriver.Chrome()
driver.get("https://www.hostelworld.com/")

# %%
slct=driver.find_element(By.CLASS_NAME,"native-input")
slct.click()

# %%
srch = driver.find_element(By.CLASS_NAME,"native-input")
srch.send_keys('London')

# %%
slct=driver.find_element(By.CLASS_NAME,"item-text")
slct.click()

# %%
go = driver.find_element(By.XPATH, '//button[@class="btn-content medium-button icon-only"]')
go.click()

# %%
name=[]
names = driver.find_elements(By.XPATH,'//div[@class="property-name"]/span')
for i in names:
    n = i.text
    name.append(n)
dist=[]
dists = driver.find_elements(By.XPATH,'//span[@class="distance-description"]')
for i in dists:
    d = i.text
    dist.append(d)
rate=[]
rates = driver.find_elements(By.XPATH,'//span[@class="number"]')
for i in rates:
    r = i.text
    rate.append(r)
tot=[]
tots = driver.find_elements(By.XPATH,'//div[@class="review"]')
for i in tots:
    t = i.text
    tot.append(t)
pri=[]
pris = driver.find_elements(By.XPATH,'//div[@class="accommodation-price unavailable"]')
for i in pris:
    p = i.text
    pri.append(p)

# %%
print(pri)
# Out:
# ['No Privates Available', 'No Dorms Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Dorms Available', 'No Privates Available', 'No Dorms Available', 'No Privates Available']

# %%
urls = []
start = 0
end = 1

for page in range(start, end):
   
    elements = driver.find_elements(By.XPATH, '//a[@class="property-card-container horizontal"]')
    for element in elements:
        urls.append(element.get_attribute('href'))
for url in urls:
    print(url)
# Out:
# https://www.hostelworld.com/pwa/hosteldetails.php/St%20Christopher's%20Village/London/502?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Onefam%20Notting%20Hill/London/291433?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Urbany%20Hostel%20London/London/303427?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Generator%20London/London/510?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/NX%20London%20Hostel/London/15204?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Safestay%20London%20Elephant%20&%20Castle/London/55551?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Palmers%20Lodge%20-%20Swiss%20Cottage/London/14348?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Safestay%20London%20Kensington%20Holland%20Park/London/93920?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Clink261/London/516?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/No.8%20Willesden%20Hostel%20London/London/18420?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Destinations%20Hostels%20@%20The%20Gallery/London/314563?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Phoenix%20Hostel/London/48221?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Queen%20Elizabeth%20Chelsea/London/50443?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/No.8%20Seven%20Sisters/London/91108?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/London%20Backpackers/London/527?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Hostelle%20-%20women%20only%20hostel%20London/London/316723?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Prime%20Backpackers%20Angel/London/93902?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Kabannas%20London%20St%20Pancras/London/7010?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/St%20Christopher's%20Camden/London/505?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/St%20Christopher's%20Inn%20-%20London%20Bridge/London/503?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/St%20Christopher's%20Greenwich/London/501?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Saint%20James%20Backpackers/London/70909?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Bell%20House%20Hostel/London/315821?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/St%20Christopher's%20Shepherds%20Bush/London/506?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/PubLove%20@%20The%20Steam%20Engine,%20Waterloo/London/29389?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Book%20a%20Bed%20Hostels/London/14746?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/The%20Backpackshack/London/63112?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Selina%20Camden/London/310274?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/PubLove%20@%20The%20Crown,%20Battersea/London/60336?from=2023-10-02&to=2023-10-05&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Park%20Villa/London/98066?from=2023-10-02&to=2023-10-05&guests=2

# %%
fac=[]
for url in urls:
    driver.get(url)
    facs= driver.find_elements(By.XPATH,'//ul[@class="facilities"]/li')
    for i in facs:
        bb= i.text
        fac.append(bb)
print(fac)
# Out:
# ['Linen Included', 'Free WiFi', 'Free Internet Access', 'Security Lockers', 'Common Room', 'Elevator', 'Breakfast Not Included', 'Air Conditioning', 'Adaptors', 'Book Exchange', 'Hot Showers', 'Dryer', 'Reading Light', 'Hair Dryers For Hire', 'Hair Dryers', 'Iron / Ironing Board', 'Microwave', 'Washing Machine', 'Towels Not Included', 'Follows Covid-19 sanitation guidance', 'Internet access', 'Laundry Facilities', 'Towels for hire', 'Luggage Storage', '24 Hour Reception', '24 Hour Security', 'Housekeeping', 'Late check-out', 'Restaurant', 'Bar', 'Meals Available', 'Vending Machines', 'Tea & Coffee Making Facilities', 'Nightclub', 'Board Games', 'Games Room', 'Wi-Fi', 'Linen Included', 'Free WiFi', 'Free Internet Access', 'Breakfast Not Included', 'Hot Showers', 'Self-Catering Facilities', 'Flexible NRR', 'Luggage Storage', 'Tea & Coffee Making Facilities', 'Linen Included', 'Free WiFi', 'Security Lockers', 'Microwave', 'Follows Covid-19 sanitation guidance', 'Luggage Storage', '24 Hour Reception', 'Tea & Coffee Making Facilities', 'Wi-Fi', 'Linen Included', 'Free City Maps', 'Free WiFi', 'Free Internet Access', 'Wheelchair Friendly', 'Security Lockers', 'Key Card Access', 'Common Room', 'Elevator', 'Bicycle Parking', 'Breakfast Not Included', 'Meeting Rooms', 'Hot Showers', 'Reading Light', 'Safe Deposit Box', 'Card Phones', 'Towels Not Included', 'Internet access', 'Laundry Facilities', 'Airport Transfers', 'Bicycle Hire', 'Towels for hire', 'Luggage Storage', '24 Hour Reception', 'Tours/Travel Desk', 'ATM', 'Shuttle Bus', '24 Hour Security', 'Housekeeping', 'Express check-in / out', 'Late check-out', 'Restaurant', 'Bar', 'Meals Available', 'Vending Machines', 'Cafe', 'Nightclub', 'Board Games', 'Games Room', 'Pool Table', 'Foosball', 'Wi-Fi', 'Free Breakfast', 'Linen Included', 'Towels Included', 'Free WiFi', 'Security Lockers', 'Common Room', 'Hot Showers', 'Self-Catering Facilities', 'Fridge/Freezer', 'Utensils', 'Hair Dryers For Hire', 'Hair Dryers', 'Microwave', 'Washing Machine', 'Internet access', 'Laundry Facilities', 'Towels for hire', 'Housekeeping', 'Express check-in / out', 'Reception (limited hours)', 'Meals Available', 'Tea & Coffee Making Facilities', 'Board Games', 'Wi-Fi', 'Linen Included', 'Free WiFi', 'Security Lockers', 'Key Card Access', 'Common Room', 'Adaptors', 'Hot Showers', 'Cots Available', 'Dryer', 'Outdoor Terrace', 'Reading Light', 'Hair Dryers For Hire', 'Iron / Ironing Board', 'Washing Machine', 'Towels Not Included', 'Follows Covid-19 sanitation guidance', 'Internet access', 'Laundry Facilities', 'Towels for hire', 'Luggage Storage', '24 Hour Reception', 'ATM', '24 Hour Security', 'Housekeeping', 'Late check-out', 'Restaurant', 'Bar', 'Vending Machines', 'Cafe', 'Pool Table', 'Wi-Fi', 'Linen Included', 'Free WiFi', 'Free Internet Access', 'Security Lockers', 'Key Card Access', 'Common Room', 'Elevator', 'Bicycle Parking', 'BBQ', 'Breakfast Not Included', 'Adaptors', 'Book Exchange', 'Hot Showers', 'Self-Catering Facilities', 'Cooker', 'Fridge/Freezer', 'Utensils', 'Dryer', 'Outdoor Terrace', 'Reading Light', 'Hair Dryers For Hire', 'Parking', 'Hair Dryers', 'Iron / Ironing Board', 'Safe Deposit Box', 'Washing Machine', 'Flexible NRR', 'Follows Covid-19 sanitation guidance', 'Internet access', 'Laundry Facilities', 'Towels for hire', 'Luggage Storage', '24 Hour Reception', 'Postal Service', '24 Hour Security', 'Housekeeping', 'Restaurant', 'Bar', 'Meals Available', 'Vending Machines', 'Cafe', 'Tea & Coffee Making Facilities', 'PlayStation', "DVD's", 'Board Games', 'Games Room', 'Pool Table', 'Wi-Fi', 'Linen Included', 'Free WiFi', 'Security Lockers', 'Key Card Access', 'Common Room', 'Breakfast Not Included', 'Adaptors', 'Hot Showers', 'Dryer', 'Outdoor Terrace', 'Reading Light', 'Hair Dryers For Hire', 'Hair Dryers', 'Iron / Ironing Board', 'Safe Deposit Box', 'Card Phones', 'Washing Machine', 'Towels Not Included', 'Laundry Facilities', 'Towels for hire', 'Luggage Storage', '24 Hour Reception ...

# %%
print(len(name),len(dist),len(rate),len(tot),len(pri),len(fac))
# Out:
# 32 32 32 32 32 862

# %%
df = pd.DataFrame({
    'name': name[:31],'distance': dist[:31],'rate': rate[:31],'totalreview': tot[:31],'price': pri[:31],'facility': fac[:31]})
df
# Out:
#                                        name                   distance rate  \
# 0                  St Christopher's Village   - 1.8km from city centre  8.2
# 1                       Onefam Notting Hill   - 5.5km from city centre  9.0
# 2                      Urbany Hostel London   - 5.4km from city centre  8.2
# 3                          Generator London     - 3km from city centre  9.7
# 4                          NX London Hostel   - 6.1km from city centre  9.5
# 5         Safestay London Elephant & Castle   - 1.7km from city centre  7.6
# 6             Palmers Lodge - Swiss Cottage   - 6.5km from city centre  8.0
# 7   Safestay London Kensington Holland Park   - 5.8km from city centre  7.0
# 8                                  Clink261   - 3.2km from city centre  9.0
# 9              No.8 Willesden Hostel London    - 10km from city centre  7.0
# 10       Destinations Hostels @ The Gallery   - 1.7km from city centre  8.0
# 11                           Phoenix Hostel   - 4.2km from city centre  6.9
# 12                  Queen Elizabeth Chelsea   - 5.7km from city centre  9.2
# 13                       No.8 Seven Sisters     - 9km from city centre  7.3
# 14                       London Backpackers  - 11.9km from city centre  7.7
# 15      Hostelle - women only hostel London   - 5.1km from city centre  5.6
# 16                  Prime Backpackers Angel   - 3.6km from city centre  8.0
# 17               Kabannas London St Pancras   - 3.3km from city centre  9.0
# 18                  St Christopher's Camden   - 4.3km from city centre  8.0
# 19     St Christopher's Inn - London Bridge   - 1.8km from city centre  8.3
# 20               St Christopher's Greenwich   - 7.6km from city centre  7.5
# 21                  Saint James Backpackers   - 5.5km from city centre  7.7
# 22                        Bell House Hostel   - 4.2km from city centre  7.5
# 23          St Christopher's Shepherds Bush     - 7km from city centre  7.5
# 24     PubLove @ The Steam Engine, Waterloo   - 0.5km from city centre  7.6
# 25                       Book a Bed Hostels   - 6.9km from city centre  7.0
# 26                        The Backpackshack  - 10.9km from city centre  7.8
# 27       St Christopher's Oasis-Female Only   - 1.8km from city centre  7.5
# 28                            Selina Camden   - 5.5km from city centre  8.3
# 29           PubLove @ The Crown, Battersea   - 4.7km from city centre  8.1
# 30                                        -                          -  8.8
#
#    totalreview                  price                              facility
# 0      (12484)  No Privates Available                        Linen Included
# 1       (2296)     No Dorms Available                             Free WiFi
# 2        (941)  No Privates Available                  Free Internet Access
# 3       (7802)  No Privates Available                      Security Lockers
# 4       (2002)  No Privates Available                           Common Room
# 5       (5133)  No Privates Available                              Elevator
# 6      (15716)  No Privates Available                Breakfast Not Included
# 7       (1668)  No Privates Available                      Air Conditioning
# 8        (420)  No Privates Available                              Adaptors
# 9       (5100)  No Privates Available                         Book Exchange
# 10       (240)  No Privates Available                           Hot Showers
# 11      (4455)  No Privates Available                                 Dryer
# 12      (3585)  No Privates Available                         Reading Light
# 13      (4071)  No Privates Available                  Hair Dryers For Hire
# 14      (4526)  No Privates Available                           Hair Dryers
# 15        (50)  No Privates Available                  Iron / Ironing Board
# 16       (808)  No Privates Available                             Microwave
# 17      (2913)  No Privates Available                       Washing Machine
# 18      (4096)  No Privates Available                   Towels Not Included
# 19      (3551)  No Privates Available  Follows Covid-19 sanitation guidance
# 20      (3399)     No Dorms Available                       Internet access
# 21      (1924)  No Privates Available                    Laundry Facilities
# 22        (99)     No Dorms Available                       Towels for hire
# 23       (800)  No Privates Available                       Luggage Storage
# 24       (430)                      -                     24 Hour Reception
# 25      (1278)                      -                      24 Hour Security
# 26       (780)                      -                          Housekeeping
# 27       (773)                      -                        Late check-out
# 28        (55)                      -                            Restaurant
# 29       (312)                      -                                   Bar
# 30           -                      -                       Meals Available
