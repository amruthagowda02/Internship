# %%
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
import warnings
warnings.filterwarnings
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# %% [markdown]
# # Q1

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.shine.com/')

# %%
slct=driver.find_element(By.CLASS_NAME,"searchBarInput")
slct.click()

# %%
job=driver.find_element(By.CLASS_NAME,"form-control  ")
job.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
search_button = driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search_button.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags = driver.find_elements(By.XPATH, '//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH, '//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company = i.text
    company_name.append(company)

exp_tags = driver.find_elements(By.XPATH, '//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in exp_tags[0:10]:
    exp = i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'TITLE':job_title,'LOCATION':job_location,'COMPANY NAME':company_name,'EXPERIENCE REQUIRED':experience_required})
df
# Out:
#                                                TITLE       LOCATION  \
# 0                             Technical Data Analyst  Bangalore\n+9
# 1                    opening data analyst -Bangalore      Bangalore
# 2  Data Entry Operator(data analyst work) REMOTE ...  Bangalore\n+9
# 3                            Hiring For Data Analyst  Bangalore\n+8
# 4                                Senior Data Analyst  Bangalore\n+8
# 5                                       Data Analyst      Bangalore
# 6                     Mobility Data Analyst - IN/MKR      Bangalore
# 7                                Senior Data Analyst      Bangalore
# 8  hiring for data entry analyst ( position data ...  Bangalore\n+9
# 9  hiring for data entry analyst ( position data ...  Bangalore\n+9
#
#                              COMPANY NAME EXPERIENCE REQUIRED
# 0  krishna consultancy.. hiring for co...          4 to 9 Yrs
# 1          provizor it services pvt. ltd.          2 to 5 Yrs
# 2                        prime services..           0 to 1 Yr
# 3        harjai computers private limited          2 to 5 Yrs
# 4        harjai computers private limited          0 to 2 Yrs
# 5                             true caller          3 to 5 Yrs
# 6                             bosch group          4 to 6 Yrs
# 7                             true caller          5 to 7 Yrs
# 8                        prime services..           0 to 1 Yr
# 9                      realtech solutions           0 to 1 Yr

# %% [markdown]
# # Q2

# %%
driver=webdriver.Chrome()
driver.get('https://www.shine.com/')

# %%
slct=driver.find_element(By.CLASS_NAME,"searchBarInput")
slct.click()

# %%
job=driver.find_element(By.CLASS_NAME,"form-control  ")
job.send_keys('Data scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
search_button = driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search_button.click()

# %%
job_title=[]
job_location=[]
company_name=[]

# %%
title_tags = driver.find_elements(By.XPATH, '//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH, '//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company = i.text
    company_name.append(company)

# %%
df=pd.DataFrame({'TITLE':job_title,'LOCATION':job_location,'COMPANY NAME':company_name,'EXPERIENCE REQUIRED':experience_required})
df
# Out:
#                                                TITLE        LOCATION  \
# 0                                     Data Scientist       Bangalore
# 1                                 SR. DATA SCIENTIST       Bangalore
# 2                 Senior Data Scientist- ML Engineer       Bangalore
# 3                                 Data Scientist III       Bangalore
# 4       Data Scientist Hiring Fresher and Experience  Bangalore\n+17
# 5  Opening for Computer executive, data typing , ...   Bangalore\n+9
# 6                                     Data Scientist   Bangalore\n+6
# 7                         Senior Data Scientist, AWS       Bangalore
# 8                         Data Scientist Recruitment  Bangalore\n+17
# 9  Data Engineer II, Amazon WFM Tech Enterprise Data       Bangalore
#
#                     COMPANY NAME EXPERIENCE REQUIRED
# 0              the fashion cosmo          4 to 9 Yrs
# 1  te connectivity india pvt ltd          2 to 5 Yrs
# 2              sap india pvt ltd           0 to 1 Yr
# 3                         inmobi          2 to 5 Yrs
# 4       kavya staffing solutions          0 to 2 Yrs
# 5             realtech solutions          3 to 5 Yrs
# 6                quiscon biotech          4 to 6 Yrs
# 7                         amazon          5 to 7 Yrs
# 8       kavya staffing solutions           0 to 1 Yr
# 9                         amazon           0 to 1 Yr

# %% [markdown]
# # Q3

# %%
driver=webdriver.Chrome()
driver.get('https://www.shine.com/')

# %%
slct=driver.find_element(By.CLASS_NAME,"searchBarInput")
slct.click()

# %%
job=driver.find_element(By.CLASS_NAME,"form-control  ")
job.send_keys('Data scientist')

# %%
search_button = driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search_button.click()

# %%
slct_loc=driver.find_element(By.CLASS_NAME,"filter_filter_lists_items__wlFfo")
slct_loc.click()

# %%
delhi_option = driver.find_element(By.XPATH,'//li[@class="filter_filter_option_item__bvdpQ"][7]')
delhi_option.click()

# %%
slct_=driver.find_element(By.XPATH,'//div[@class="filter_btnWrap__5ToWy"]//button[2]')
slct_.click()

# %%
slct_sal=driver.find_element(By.CLASS_NAME,)
slct_sal.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags = driver.find_elements(By.XPATH, '//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH, '//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company = i.text
    company_name.append(company)

exp_tags = driver.find_elements(By.XPATH, '//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in exp_tags[0:10]:
    exp = i.text
    experience_required.append(exp)

# %%
df=pd.DataFrame({'TITLE':job_title,'LOCATION':job_location,'COMPANY NAME':company_name,'EXPERIENCE REQUIRED':experience_required})
df
# Out:
#                                     TITLE   LOCATION  \
# 0                          Data Scientist  Delhi\n+6
# 1                    DATA SCIENTIST DELHI      Delhi
# 2                          Data Scientist  Delhi\n+6
# 3              Apply for Data Entry Delhi      Delhi
# 4                     Data Entry Operator  Delhi\n+9
# 5                  Technical Data Analyst  Delhi\n+9
# 6                        DATA ENTRY DELHI      Delhi
# 7                      Require Data Entry      Delhi
# 8  Urgent requirement Data Entry Operator  Delhi\n+9
# 9    GIS-Utility Network Model Consultant  Delhi\n+8
#
#                              COMPANY NAME EXPERIENCE REQUIRED
# 0                         quiscon biotech           0 to 1 Yr
# 1                     skyleaf consultants          3 to 6 Yrs
# 2                         quiscon biotech          0 to 3 Yrs
# 3                          rise placement          0 to 3 Yrs
# 4  apex trading & softech solutions hi...           0 to 1 Yr
# 5  krishna consultancy.. hiring for co...          4 to 9 Yrs
# 6                alpine manpower services          0 to 3 Yrs
# 7                alpine manpower services          0 to 3 Yrs
# 8                 v-tech data outsourcing          0 to 2 Yrs
# 9                      wipro technologies         6 to 11 Yrs

# %% [markdown]
# # Q4

# %%
driver = webdriver.Chrome()
driver.get("https://www.flipkart.com/")

# %%
sr=driver.find_element(By.CLASS_NAME,"Pke_EE")
sr.send_keys('sunglasses')

# %%
search_button = driver.find_element(By.CLASS_NAME,"_2iLD__" )
search_button.click()

# %%
B=[]
D=[]
P=[]

# %%
B_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in B_tags:
    BB = i.text
    B.append(BB)
P_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in P_tags:
    PP = i.text
    P.append(PP)
    
D_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in D_tags:
    DD = i.text
    D.append(DD)

# %%
print(len(P),len(B),len(D))
# Out:
# 40 40 36

# %%
min_ = min(len(P), len(B), len(D))
P = P[:min_]
B = B[:min_]
D = D[:min_]
df=pd.DataFrame({'TITLE':B,'RATING':D,"PRICE":P})
df
# Out:
#                TITLE                                             RATING  \
# 0      VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)
# 1      VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)
# 2           Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 3           Fastrack              UV Protection Aviator Sunglasses (58)
# 4           Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 5           Fastrack       UV Protection Aviator Sunglasses (Free Size)
# 6            STACTOR  by Lenskart Polarized, UV Protection Rectangul...
# 7      VINCENT CHASE         UV Protection Retro Square Sunglasses (54)
# 8          Rich Club      UV Protection Wayfarer Sunglasses (Free Size)
# 9           Fastrack                UV Protection Round Sunglasses (54)
# 10         ROYAL SON     Polarized, UV Protection Round Sunglasses (51)
# 11     VINCENT CHASE         UV Protection Retro Square Sunglasses (54)
# 12         Rich Club    UV Protection Wayfarer, Aviator Sunglasses (50)
# 13  shah collections           UV Protection Over-sized Sunglasses (60)
# 14            PIRASO  Polarized, UV Protection Retro Square Sunglass...
# 15       Eyewearlabs  by Lenskart Polarized, UV Protection Aviator S...
# 16     VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...
# 17     VINCENT CHASE              UV Protection Aviator Sunglasses (58)
# 18       Sunglassess     Polarized, UV Protection Round Sunglasses (50)
# 19          Fastrack         UV Protection Retro Square Sunglasses (51)
# 20     VINCENT CHASE              UV Protection Aviator Sunglasses (57)
# 21       john jacobs  Gradient, UV Protection Wayfarer Sunglasses (F...
# 22            GANSTA             UV Protection Wayfarer Sunglasses (58)
# 23          Fastrack              Gradient Retro Square Sunglasses (60)
# 24          Fastrack  by Lenskart UV Protection Clubmaster Sunglasse...
# 25         90stethix  UV Protection Wayfarer, Sports, Spectacle , Re...
# 26         ROYAL SON      UV Protection Wayfarer Sunglasses (Free Size)
# 27     VINCENT CHASE  UV Protection, Riding Glasses Retro Square, Re...
# 28           ROADWAY  Polarized, UV Protection Wayfarer Sunglasses (56)
# 29          Fastrack        UV Protection Shield Sunglasses (Free Size)
# 30      Singco India      UV Protection Wayfarer Sunglasses (Free Size)
# 31       Eyewearlabs  UV Protection Retro Square Sunglasses (Free Size)
# 32          Fastrack  by Lenskart Polarized, UV Protection Aviator S...
# 33        Sunglasses              Polarized Rectangular Sunglasses (60)
# 34          Fastrack                   Mirrored Aviator Sunglasses (58)
# 35         CLICKEDIN             UV Protection Wayfarer Sunglasses (50)
#
#      PRICE
# 0     ₹549
# 1     ₹849
# 2     ₹499
# 3     ₹799
# 4     ₹549
# 5     ₹549
# 6     ₹799
# 7     ₹949
# 8     ₹488
# 9     ₹599
# 10    ₹664
# 11    ₹949
# 12    ₹495
# 13    ₹275
# 14    ₹279
# 15  ₹1,299
# 16    ₹849
# 17    ₹849
# 18    ₹569
# 19    ₹849
# 20    ₹849
# 21  ₹4,500
# 22    ₹212
# 23    ₹549
# 24    ₹649
# 25    ₹299
# 26    ₹686
# 27    ₹849
# 28    ₹264
# 29    ₹549
# 30    ₹449
# 31  ₹1,543
# 32    ₹599
# 33    ₹687
# 34    ₹449
# 35    ₹199

# %% [markdown]
# # Q5

# %%
driver = webdriver.Chrome()
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
rat=[]
sm=[]
fl=[]

# %%
R_tags = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in R_tags:
    RE = i.text
    rat.append(RE)
    
    
sm_tags = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in sm_tags:
    SM = i.text
    sm.append(SM)
    
fl_tags = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in fl_tags:
    FULL = i.text
    fl.append(FULL)

# %%
df=pd.DataFrame({'TITLE':rat,'RATING':sm,"PRICE":fl})
df
# Out:
#   TITLE               RATING  \
# 0     5  Best in the market!
# 1     5            Wonderful
# 2     5    Worth every penny
# 3     5            Must buy!
# 4     5       Classy product
# 5     5             Terrific
# 6     5            Fabulous!
# 7     5            Just wow!
# 8     5       Classy product
# 9     5            Must buy!
#
#                                                PRICE
# 0                                        Good Camera
# 1                             This is amazing at all
# 2  Feeling awesome after getting the delivery of ...
# 3  Go for iPhone 11 , if confused between iPhone ...
# 4  Camera is awesome\nBest battery backup\nA perf...
# 5                                     Very very good
# 6                    Super🔥 and good performance 👌❤️
# 7                                  Perfect Product!!
# 8                                       Photos super
# 9                                It’s really awesome

# %% [markdown]
# # Q6

# %%
driver = webdriver.Chrome()
driver.get("https://www.flipkart.com/")

# %%
sr=driver.find_element(By.CLASS_NAME,"Pke_EE")
sr.send_keys('sneakers')

# %%
search_button = driver.find_element(By.CLASS_NAME,"_2iLD__" )
search_button.click()

# %%
B=[]
D=[]
P=[]

# %%
B_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in B_tags:
    BB = i.text
    B.append(BB)
    
P_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in P_tags:
    PP = i.text
    P.append(PP)
    
D_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in D_tags:
    DD = i.text
    D.append(DD)

# %%
print(len(P),len(B),len(D))
# Out:
# 40 40 36

# %%
min_ = min(len(P), len(B), len(D))
P = P[:min_]
B = B[:min_]
D = D[:min_]
df=pd.DataFrame({'TITLE':B,'RATING':D,"PRICE":P})
df
# Out:
#                     TITLE                                             RATING  \
# 0                    aadi  Lightweight,Comfort,Summer,Trendy,Walking,Outd...
# 1                HOTSTYLE                                   Sneakers For Men
# 2                   asian                                   Sneakers For Men
# 3                   asian                                   Sneakers For Men
# 4         U.S. POLO ASSN.                           CLARKIN Sneakers For Men
# 5             kardam&sons  Fashionable Canvas Casual Partywear Outdoor Sn...
# 6                  BIZDOM  Synthetic Leather |Lightweight|Comfort|Summer|...
# 7                  MEGPAR                                   Sneakers For Men
# 8                    aadi  Stylish Sneakers Shoes for Women And Girls Sne...
# 9                WOODLAND  Mesh |Lightweight|Comfort|Summer|Trendy|Walkin...
# 10                 Shozie            Casual Sneakrs For Men Sneakers For Men
# 11                   aadi                    X-Ray 2 Square Sneakers For Men
# 12               Vellinto  Tarzan-04 White Sneakers,Casuals,Loafers,Styli...
# 13                   PUMA                 Rerooted Classics Sneakers For Men
# 14                  asian                                   Sneakers For Men
# 15  HRX by Hrithik Roshan                         Radiant Sneakers For Women
# 16               RapidBox                                   Sneakers For Men
# 17                 Kraasa                                   Sneakers For Men
# 18               Takshter                                   Sneakers For Men
# 19               WOODLAND                                   Sneakers For Men
# 20               RapidBox  kardam&sons luxury fashionable Stylish Light W...
# 21                   ATOM  kardam&sons luxury fashionable Stylish Light W...
# 22            kardam&sons                                   Sneakers For Men
# 23            kardam&sons  Stylish Comfortable Casual Sneakers Shoes for ...
# 24           JACK & JONES     Women Sneakers Casual Shoes Sneakers For Women
# 25                 ADIDAS                                   Sneakers For Men
# 26                 Shozie  Lightweight,Comfort,Summer,Trendy,Walking,Outd...
# 27                 Shozie               Spring Edge Alpha 1 Sneakers For Men
# 28           JACK & JONES                         Wellshore Sneakers For Men
# 29                   aadi                                   Sneakers For Men
# 30                   ATOM  Lifestyle Shoes for Men | Comfortable & Durabl...
# 31               Afrojack                                   Sneakers For Men
# 32                   aadi                                   Sneakers For Men
# 33               RED TAPE  Exclusive Rap & Dance Shoes For Boys Sneakers ...
# 34                 BIZDOM  Skypee-32 Grey Highneck Canvas,Loafers,Walking...
# 35                 DUCATI                    Skypy-31 Shoes Sneakers For Men
#
#      PRICE
# 0     ₹279
# 1     ₹398
# 2     ₹822
# 3     ₹622
# 4   ₹1,558
# 5     ₹341
# 6     ₹499
# 7     ₹384
# 8     ₹279
# 9   ₹1,751
# 10    ₹499
# 11    ₹279
# 12    ₹603
# 13  ₹3,330
# 14    ₹622
# 15  ₹1,368
# 16    ₹699
# 17    ₹399
# 18    ₹759
# 19  ₹1,880
# 20    ₹695
# 21  ₹1,285
# 22    ₹394
# 23    ₹394
# 24    ₹749
# 25  ₹3,120
# 26    ₹520
# 27    ₹499
# 28    ₹749
# 29    ₹528
# 30  ₹1,585
# 31    ₹636
# 32    ₹279
# 33  ₹1,679
# 34    ₹499
# 35  ₹1,049

# %% [markdown]
# # Q7

# %%
driver = webdriver.Chrome()
driver.get("https://www.amazon.in/")

# %%
sr=driver.find_element(By.CLASS_NAME,"nav-input.nav-progressive-attribute")
sr.send_keys('laptop')

# %%
search_button = driver.find_element(By.CLASS_NAME, "nav-search-submit.nav-sprite")
search_button.click()

# %%
cpu_type = driver.find_element(By.ID, "p_n_feature_thirteen_browse-bin/12598163031")
cpu_type.click()

option = driver.find_element(By.ID, "p_n_feature_thirteen_browse-bin/16757432031")
option.click()

# %%
T=[]
R=[]
P=[]

# %%
T_tags = driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in T_tags:
    TT = i.text
    T.append(TT)
    
R_tags = driver.find_elements(By.XPATH,'//span[@class="a-size-base puis-bold-weight-text"]')
for i in R_tags:
    RR = i.text
    R.append(RR)

P_tags = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in P_tags:
    PP = i.text
    P.append(PP)

# %%
df=pd.DataFrame({'TITLE':T,'RATING':R,"PRICE":P})
df
# Out:
#                                                 TITLE RATING     PRICE
# 0   Lenovo IdeaPad Slim 5 13th Gen Intel Core i5 1...    5.0    71,990
# 1   HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (3...    4.1    37,990
# 2   HP Laptop 15s, 12th Gen Intel Core i3-1215U, 1...    4.1    40,927
# 3   Acer Aspire Lite 11th Gen Intel Core i3 Premiu...    3.9    31,990
# 4   HP Laptop 15s, Intel Celeron N4500, 15.6 inch(...    3.3    28,990
# 5   Chuwi HeroBook Pro 14.1'' Laptop, 8GB RAM 256G...    3.9    19,990
# 6   ASUS [SmartChoice] Vivobook 15, Intel Celeron ...    3.9    30,990
# 7   HP 15 Laptop, 11th Gen i3-1115G4 15.6 inch(39....    4.1    37,680
# 8   Acer Aspire Lite 11th Gen Intel Core i5-1155G7...    3.5    41,999
# 9   Chuwi HeroBook Pro 14.1'' Laptop, 8GB RAM 256G...    3.9    19,990
# 10  JioBook 11 (2023) NB1112MM(BLU) (Mediatek 8788...    3.1    16,499
# 11  HP Chromebook x360 Intel Celeron N4120 14 inch...    3.9    22,990
# 12  Lenovo IdeaPad Slim 5 Intel Core i5 12450H 14"...    4.2    56,990
# 13  Acer Aspire Lite AMD Ryzen 5 5500U Premium Thi...    3.8    37,990
# 14  HP Laptop 15s, 11th Gen Intel Core i3-1115G4, ...    4.1    36,927
# 15  MSI Modern 15, Intel 11th Gen. i5-1155G7, 40CM...    4.5    42,990
# 16  Acer Aspire Lite AMD Ryzen 5 5500U Premium Thi...    3.8    35,999
# 17  Lenovo IdeaPad 1 Intel Core Celeron N4020 14" ...    4.1    25,490
# 18  HP Laptop 15s, 12th Gen Intel Core i3-1215U, 1...    3.8    44,090
# 19  HP Laptop 15s, Intel Pentium Silver N6000, 15....    5.0    32,990
# 20  Chuwi HeroBook Air Laptop 11" - Intel Celeron ...    3.9    16,990
# 21  Apple 2023 MacBook Air Laptop with M2 chip: 38...    4.1  1,26,990
# 22  HP Chromebook 15a Intel Celeron N4500 15.6inch...    2.7    22,990
# 23  BKN® Mini Premium Metal Folding Portable Lapto...    4.3       298

# %% [markdown]
# # Q8

# %%
driver = webdriver.Chrome()
driver.get("https://www.azquotes.com/")

# %%
elements = driver.find_elements(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a") 
elements[0].click()

# %%
Q=[]
A=[]
T=[]

# %%
Q_tags = driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in Q_tags:
    QT = i.text
    Q.append(QT)
A_tags = driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in A_tags:
    AT = i.text
    A.append(AT)

T_tags = driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in T_tags:
    TT = i.text
    T.append(TT)

# %%
print(len(Q),len(A),len(T))
# Out:
# 100 100 100

# %%
df=pd.DataFrame({'QUOTE':Q,'AUTHOR':A,"TYPE":T})
df.head(20)
# Out:
#                                                 QUOTE                 AUTHOR  \
# 0   The essence of strategy is choosing what not t...         Michael Porter
# 1   One cannot and must not try to erase the past ...             Golda Meir
# 2   Patriotism means to stand by the country. It d...     Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...         Nelson Mandela
# 4   You have to love a nation that celebrates its ...           Erma Bombeck
# 5   Be more concerned with your character than you...            John Wooden
# 6   Weak people revenge. Strong people forgive. In...        Albert Einstein
# 7   A mind is like a parachute. It doesn't work if...            Frank Zappa
# 8   Never be afraid to raise your voice for honest...       William Faulkner
# 9   There are three kinds of men. The one that lea...            Will Rogers
# 10  A strong nation, like a strong person, can aff...           Jimmy Carter
# 11  The difference between stupidity and genius is...        Albert Einstein
# 12  We the people are the rightful masters of both...        Abraham Lincoln
# 13  With or without religion, you would have good ...        Steven Weinberg
# 14  Human kindness has never weakened the stamina ...  Franklin D. Roosevelt
# 15  A person who never made a mistake never tried ...        Albert Einstein
# 16  My mission in life is not merely to survive, b...           Maya Angelou
# 17  Life is short, Break the Rules. Forgive quickl...             Mark Twain
# 18  This country will not be a good place for any ...     Theodore Roosevelt
# 19  In a world filled with hate, we must still dar...        Michael Jackson
#
#                                         TYPE
# 0   Essence, Deep Thought, Transcendentalism
# 1                  Inspiration, Past, Trying
# 2                        Country, Peace, War
# 3         Inspirational, Motivational, Death
# 4               4th Of July, Food, Patriotic
# 5         Inspirational, Success, Basketball
# 6               Strong, Revenge, Intelligent
# 7          Inspirational, Teacher, Religious
# 8                      Truth, Honesty, Lying
# 9                   Funny, Reading, Learning
# 10            Strong, Thoughtful, Compassion
# 11                         Love, Funny, Life
# 12            Freedom, Men, Democracies Have
# 13                   God, Religious, Atheist
# 14              Respect, Kindness, Character
# 15       Inspirational, Motivational, Change
# 16            Inspirational, Life, Inspiring
# 17                 Love, Inspirational, Life
# 18           Inspiring, Country, 4th Of July
# 19                Inspirational, Dream, Hate

# %% [markdown]
# # Q9

# %%
driver = webdriver.Chrome()
driver.get("https://www.jagranjosh.com/")

# %%
elements = driver.find_elements(By.XPATH, "/html/body/div/header/nav/div/div/div[3]/ul/li[3]/a")
elements[0].click()

# %%
pm=driver.find_elements(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
pm[0].click()

# %%
names = []
born_dead=[]
TO=[]
rmk=[]
name_tags = driver.find_elements(By.XPATH, '//div[@class="table-box"]//table/tbody/tr/td[2] ')
for i in name_tags:
    name = i.text
    names.append(name)

bd_tags = driver.find_elements(By.XPATH, '//div[@class="table-box"]//table/tbody/tr/td[3] ')
for i in bd_tags:
    BD = i.text
    born_dead.append(BD)

term_tags = driver.find_elements(By.XPATH, '//div[@class="table-box"]//table/tbody/tr/td[4] ')
for i in term_tags:
    title = i.text
    TO.append(title)

rmk_tags = driver.find_elements(By.XPATH, '//div[@class="table-box"]//table/tbody/tr/td[5] ')
for i in rmk_tags:
    rank = i.text
    rmk.append(rank)

# %%
print(len(names),len(born_dead),len(TO))
# Out:
# 20 19 19

# %%
max_length = max(len(names), len(born_dead))
names += [np.nan] * (max_length - len(names))
TO += [np.nan] * (max_length-len(TO))
rmk += [np.nan] * (max_length-len(rmk))
born_dead += [np.nan] * (max_length - len(born_dead))
df=pd.DataFrame({'NAME':names,'BORN-DEAD':born_dead,"TERM OF OFC":TO,"rank":rmk})
df
# Out:
#                                            NAME     BORN-DEAD  \
# 0                             Jawahar Lal Nehru   (1889–1964)
# 1                     Gulzarilal Nanda (Acting)   (1898-1998)
# 2                           Lal Bahadur Shastri   (1904–1966)
# 3                   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                                 Indira Gandhi   (1917–1984)
# 5                                 Morarji Desai   (1896–1995)
# 6                                  Charan Singh   (1902–1987)
# 7                                 Indira Gandhi   (1917–1984)
# 8                                  Rajiv Gandhi   (1944–1991)
# 9                                   V. P. Singh   (1931–2008)
# 10                              Chandra Shekhar   (1927–2007)
# 11                          P. V. Narasimha Rao   (1921–2004)
# 12                         Atal Bihari Vajpayee  (1924- 2018)
# 13                             H. D. Deve Gowda   (born 1933)
# 14                           Inder Kumar Gujral   (1919–2012)
# 15                         Atal Bihari Vajpayee   (1924-2018)
# 16                               Manmohan Singh   (born 1932)
# 17                                Narendra Modi   (born 1950)
# 18                                Narendra Modi   (born 1950)
# 19  List of Nicknames of Indian Prime Ministers           NaN
#
#                                           TERM OF OFC  \
# 0   15 August 1947 to 27 May 1964\n16 years, 286 days
# 1                27 May 1964 to 9 June 1964,\n13 days
# 2    9 June 1964 to 11 January 1966\n1 year, 216 days
# 3         11 January 1966 to 24 January 1966\n13 days
# 4   24 January 1966 to 24 March 1977\n11 years, 59...
# 5   24 March 1977 to  28 July 1979 \n2 year, 126 days
# 6           28 July 1979 to 14 January 1980\n170 days
# 7   14 January 1980 to 31 October 1984\n4 years, 2...
# 8   31 October 1984 to 2 December 1989\n5 years, 3...
# 9       2 December 1989 to 10 November 1990\n343 days
# 10         10 November 1990 to 21 June 1991\n223 days
# 11     21 June 1991 to 16 May 1996\n4 years, 330 days
# 12                16 May 1996 to 1 June 1996\n16 days
# 13             1 June 1996 to 21 April 1997\n324 days
# 14          21 April 1997 to 19 March 1998 \n332 days
# 15    19 March 1998 to 22 May 2004 \n6 years, 64 days
# 16    22 May 2004 to 26 May 2014   \n10 years, 4 days
# 17                                 26 May 2014 - 2019
# 18                             30 May 2019- Incumbent
# 19                                                NaN
#
#                                                  rank
# 0   The first prime minister of India and the long...
# 1                            First acting PM of India
# 2   He has given the slogan of 'Jai Jawan Jai Kisa...
# 3                                                   -
# 4                First female Prime Minister of India
# 5   Oldest to become PM (81 years old) and first t...
# 6             Only PM who did not face the Parliament
# 7   The first lady who served as PM for the second...
# 8                Youngest to become PM (40 years old)
# 9   First PM to step down after a vote of no confi...
# 10              He belongs to  Samajwadi Janata Party
# 11                          First PM from South India
# 12                             PM for shortest tenure
# 13                          He belongs to  Janata Dal
# 14                                             ------
# 15   The first non-congress PM who completed a ful...
# 16                                      First Sikh PM
# 17  4th Prime Minister of India who served two con...
# 18  First non-congress PM with two consecutive ten...
# 19                                                NaN

# %% [markdown]
# # Q 10

# %%
driver = webdriver.Chrome()
driver.get('https://www.motor1.com/')
driver.find_elements(By.CLASS_NAME, "m1-search-panel-input.m1-search-form-text")[0].send_keys('50 most expensive cars')

# %%
driver.find_element(By.CLASS_NAME,"m1-search-form-button-wrapper").click()

# %%
driver.find_element(By.CLASS_NAME./features/308149/most-expensive-new-cars-ever/")

# %%
cars=[]
car_tags = driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in car_tags:
    list = i.text
    cars.append(list)

# %%
price=[]
rs_tags = driver.find_elements(By.XPATH,"//strong[contains(text(), 'Price: $')]")
for i in rs_tags:
    list = i.text
    price.append(list)

# %%
print(len(cars),len(price))
# Out:
# 51 48

# %%
max_length = max(len(cars), len(price))
cars += [np.nan] * (max_length - len(cars))
price += [np.nan] * (max_length - len(price))
df=pd.DataFrame({'cars':cars,'price':price})
df
# Out:
#                                   cars                        price
# 0                  Aston Martin Valour          Price: $1.5 Million
# 1                         McLaren Elva          Price: $1.7 Million
# 2                          Czinger 21C          Price: $1.7 Million
# 3                        Ferrari Monza          Price: $1.7 Million
# 4                   Gordon Murray T.33          Price: $1.7 Million
# 5                    Koenigsegg Gemera          Price: $1.7 Million
# 6                          Zenvo TSR-S          Price: $1.7 Million
# 7                   Hennessey Venom F5          Price: $1.8 Million
# 8                      Bentley Bacalar          Price: $1.9 Million
# 9        Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 10              Bentley Mulliner Batur          Price: $2.0 Million
# 11                        Deus Vayanne          Price: $2.0 Million
# 12                         SSC Tuatara          Price: $2.0 Million
# 13                         Lotus Evija          Price: $2.1 Million
# 14                 Aston Martin Vulcan          Price: $2.3 Million
# 15                          Delage D12          Price: $2.3 Million
# 16                 Ferrari Daytona SP3          Price: $2.3 Million
# 17                   McLaren Speedtail          Price: $2.3 Million
# 18                        Rimac Nevera          Price: $2.4 Million
# 19                       Pagani Utopia          Price: $2.5 Million
# 20                Pininfarina Battista          Price: $2.5 Million
# 21                  Gordon Murray T.50          Price: $2.6 Million
# 22                Lamborghini Countach          Price: $2.6 Million
# 23            Mercedes-AMG Project One          Price: $2.7 Million
# 24                        Zenvo Aurora          Price: $2.8 Million
# 25                 Aston Martin Victor          Price: $3.0 Million
# 26         Hennessey Venom F5 Roadster          Price: $3.0 Million
# 27                    Koenigsegg Jesko          Price: $3.2 Million
# 28               Aston Martin Valkyrie          Price: $3.4 Million
# 29           W Motors Lykan Hypersport          Price: $3.6 million
# 30                       McLaren Solus          Price: $3.7 Million
# 31                    Lamborghini Sian          Price: $3.9 Million
# 32                    Koenigsegg CC850          Price: $4.5 Million
# 33     Bugatti Chiron Super Sport 300+          Price: $4.7 Million
# 34                  Lamborghini Veneno          Price: $4.8 Million
# 35                      Bugatti Bolide          Price: $5.0 Million
# 36           Pininfarina B95 Speedster          Price: $5.4 Million
# 37                     Bugatti Mistral          Price: $5.8 Million
# 38                 Pagani Huayra Imola          Price: $6.4 Million
# 39                        Bugatti Divo          Price: $7.4 Million
# 40                 SP Automotive Chaos          Price: $7.5 Million
# 41                    Pagani Codalunga          Price: $8.0 Million
# 42                        777 Hypercar          Price: $9.0 Million
# 43            Mercedes-Maybach Exelero         Price: $10.8 Million
# 44                  Bugatti Centodieci         Price: $12.8 Million
# 45             Bugatti Chiron Profilée         Price: $13.4 Million
# 46                Rolls-Royce Sweptail  Price: $28.0 Million (est.)
# 47            Bugatti La Voiture Noire    Price: $30 Million (est.)
# 48              Rolls-Royce Boat Tail*                          NaN
# 49  Rolls-Royce La Rose Noire Droptail                          NaN
# 50    Most Expensive Cars In The World                          NaN
